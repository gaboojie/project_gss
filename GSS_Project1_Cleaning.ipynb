# %% [markdown]
# Load selected variables into selected_gss_data.csv:

# %%
import pandas as pd
#
var_list = ['year', 'age', 'educ', 'relig', 'happy', 'zodiac','polviews', 'degree'] # List of variables you want to save
output_filename = 'selected_gss_data.csv' # Name of the file you want to save the data to
#
modes = ['w','a'] # Has write mode and append mode
phase = 0 # Starts in write mode; after one iteration of loop, switches to append mode
#
for k in range(3): # for each chunk of the data
    url = 'https://github.com/DS3001/project_gss/raw/main/gss_chunk_' + str(1+k) + '.parquet' # Create url to the chunk to be processed
    #print(url) # Check the url is correct
    df = pd.read_parquet(url) # Download this chunk of data
    #print(df.head()) # Visually inspect the first few rows
    df.loc[:,var_list].to_csv(output_filename, # specifies target file to save the chunk to
                              mode=modes[phase], # control write versus append
                              header=var_list, # variable names
                              index=False) # no row index saved
    phase = 1 # Switch from write mode to append mode

# %% [markdown]
# Read .csv into memory

# %%
df = pd.read_csv('selected_gss_data.csv', low_memory=False)
df.head()
# Out:
#    year   age  educ       relig          happy zodiac polviews  \
# 0  1972  23.0  16.0      jewish  not too happy    NaN      NaN
# 1  1972  70.0  10.0    catholic  not too happy    NaN      NaN
# 2  1972  48.0  12.0  protestant   pretty happy    NaN      NaN
# 3  1972  27.0  17.0       other  not too happy    NaN      NaN
# 4  1972  61.0  12.0  protestant   pretty happy    NaN      NaN
#
#                   degree
# 0             bachelor's
# 1  less than high school
# 2            high school
# 3             bachelor's
# 4            high school

# %% [markdown]
# Only include the years from 2012 to 2022 (2022 is the latest data, as the older data may reflect different trends and that is not the focus of this investigation)

# %%
# Remove any entries in table that specify the word 'year' as they represent uncleaned data and only
# specify which column represents which variable (it's data that should be completely ignored as it represents a row
# with all the variables included like at the top of the table)
df = df.loc[df['year'] != 'year']

# Cast year to number
df['year'] = pd.to_numeric(df['year'], errors='coerce')

# Filter out the years only between 2012 and 2022
df = df.loc[(df.year >= 2012) & (df.year <= 2022)]

# Now only includes data from 2012 to 2022
df.head()
# Out:
#        year   age  educ       relig         happy     zodiac  \
# 55089  2012  22.0  16.0    catholic    very happy      libra
# 55090  2012  21.0  12.0    catholic    very happy      aries
# 55091  2012  42.0  12.0  protestant  pretty happy      aries
# 55092  2012  49.0  13.0  protestant    very happy  capricorn
# 55093  2012  70.0  16.0  protestant    very happy     taurus
#
#                            polviews       degree
# 55089  moderate, middle of the road   bachelor's
# 55090         slightly conservative  high school
# 55091         slightly conservative  high school
# 55092         slightly conservative  high school
# 55093                       liberal   bachelor's

# %% [markdown]
# See count of NAs in dataframe df:

# %%
print("Rows, columns:", df.shape)
df.isna().sum()
# Out:
# Rows, columns: (17303, 8)
# year          0
# age         572
# educ        101
# relig       211
# happy        72
# zodiac      995
# polviews    587
# degree       31
# dtype: int64

# %% [markdown]
# Change column names:

# %%
df = df.rename(columns = {'educ':'education',
                    'relig':'religion',
                    'polviews':'political_view', 'degree':'degree_obtained'})

# %% [markdown]
# Clean religion variable: (by capitalizing/editing any religion type and replacing any NAs with unknown).

# %%
# Capitalize religion type
to_replace = {'catholic': 'Catholic', 'protestant': 'Protestant', 'christian': 'Christian', 'none': 'None',
              'orthodox-christian': 'Orthodox-Christian', 'hinduism': 'Hinduism', 'other': 'Other', 'muslim/islam': 'Islam',
              'other eastern religions': 'Other Eastern Religions', 'buddhism': 'Buddhism', 'inter-nondenominational': 'Inter-Nondenominational',
              'native american': 'Native American', 'relig': 'Unknown'}
df['religion'] = df['religion'].map(to_replace)

# Replace any NAs with unknown and
df['religion'].fillna('Unknown', inplace=True) #replace NAs with 'unknown'

# Print uniques
print(df['religion'].unique())
# Out:
# ['Catholic' 'Protestant' 'Christian' 'None' 'Orthodox-Christian'
#  'Hinduism' 'Unknown' 'Other' 'Islam' 'Other Eastern Religions' 'Buddhism'
#  'Inter-Nondenominational' 'Native American']

# %% [markdown]
# Clean age variable: (by casting ages to integers and leaving nans as-is in order to graph as it is a numerical type)

# %%
# Typecast age to float/numeric
df['age'] = pd.to_numeric(df['age'],errors='coerce')

# Converts age to integer and removes the .0 at the end
df['age'] = df['age'].apply(lambda x: int(x) if pd.notnull(x) else x)

print(df['age'].unique())

# %% [markdown]
# Clean degree variable: (by capitalizing each degree type and replacing NA's with unknowns)

# %%
# Capitalize each degree type
to_replace = {"bachelor's": "Bachelor's", "high school": "High School", "associate/junior college": "Associate/Junior College",
              "less than high school": 'Less Than High School', "graduate": "Graduate", "unknown": 'Unknown', "degree": "Unknown"}
df['degree_obtained'] = df['degree_obtained'].map(to_replace)

# Replace NA's with Unknowns
df['degree_obtained'].fillna('Unknown', inplace=True) #replace NAs with 'unknown'

# Print uniques
print(df['degree_obtained'].unique())

# %% [markdown]
# Clean education variable: (by casting to number and as it is a numeric type, keep NA's for graphing purposes)

# %%
# Typecast education to float/numeric
df['education'] = pd.to_numeric(df['education'], errors='coerce')

# Converts age to integer and removes the .0 at the end
df['education'] = df['education'].apply(lambda x: int(x) if pd.notnull(x) else x)

# Print uniques
print(df['education'].unique())

# %% [markdown]
# Clean happy variable: (Replace any NA's with 'Unknown')

# %%
# Capitalize and recategorize
to_replace = {'very happy': 'Very Happy', 'pretty happy': 'Moderately Happy', 'not too happy': 'Not Happy'}
df['happy'] = df['happy'].map(to_replace)

# Replace any NA's with Unknown
df['happy'].fillna('Unknown', inplace=True)

# Print uniques
print(df['happy'].unique())

# %% [markdown]
# Clean political_view variable: (capitalizing and renaming certain types to be less vague and replacing any NAs with Unknown). Then, creating new variable (political_view_id) that represents how liberal (1) to how conservative (7) a person is.

# %%
# Capitalize/edit naming of political view
to_replace = {'extremely liberal': "Extremely Liberal", 'liberal': 'Liberal', 'slightly liberal': 'Slightly Liberal', 'moderate, middle of the road': 'Moderate',
              "slightly conservative": 'Slightly Conservative', 'conservative': 'Conservative', 'extremely conservative': 'Extremely Conservative'}
df['political_view'] = df['political_view'].map(to_replace)

# Map political view to political view id
to_replace = {'Extremely Liberal': 1, 'Liberal': 2, 'Slightly Liberal': 3, 'Moderate': 4, 'Slightly Conservative': 5,
              'Conservative': 6, 'Extremely Conservative': 7}
df['political_view_id'] = df['political_view'].map(to_replace)

# Replace NAs with 'Unknown' only for political_view (categorical data type) and not political_view_id (numerical data type)
df['political_view'].fillna('Unknown', inplace=True)

# Print uniques
print(df['political_view'].unique())
print(df['political_view_id'].unique())

# %% [markdown]
# Final cleaned CSV:

# %%
df.to_csv("cleaned_gss_data.csv", encoding = 'utf-8')
with open("cleaned_gss_data.csv", 'r', encoding='utf-8') as file:
    contents = file.read()
    print(contents)
# Out:
# ,year,age,education,religion,happy,zodiac,political_view,degree_obtained
# 55089,2012,22.0,16.0,Catholic,very happy,libra,"moderate, middle of the road",bachelor's
# 55090,2012,21.0,12.0,Catholic,very happy,aries,slightly conservative,high school
# 55091,2012,42.0,12.0,Protestant,pretty happy,aries,slightly conservative,high school
# 55092,2012,49.0,13.0,Protestant,very happy,capricorn,slightly conservative,high school
# 55093,2012,70.0,16.0,Protestant,very happy,taurus,liberal,bachelor's
# 55094,2012,50.0,19.0,Protestant,very happy,taurus,"moderate, middle of the road",bachelor's
# 55095,2012,35.0,15.0,Christian,pretty happy,scorpio,"moderate, middle of the road",associate/junior college
# 55096,2012,24.0,11.0,Catholic,pretty happy,scorpio,"moderate, middle of the road",less than high school
# 55097,2012,28.0,9.0,None,not too happy,libra,conservative,less than high school
# 55098,2012,28.0,17.0,None,pretty happy,taurus,liberal,bachelor's
# 55099,2012,55.0,10.0,Catholic,very happy,pisces,extremely liberal,less than high school
# 55100,2012,36.0,16.0,Protestant,pretty happy,capricorn,liberal,bachelor's
# 55101,2012,28.0,12.0,None,not too happy,capricorn,"moderate, middle of the road",high school
# 55102,2012,59.0,12.0,Protestant,very happy,sagittarius,,high school
# 55103,2012,52.0,4.0,Catholic,not too happy,sagittarius,extremely conservative,less than high school
# 55104,2012,35.0,13.0,Protestant,pretty happy,pisces,slightly liberal,high school
# 55105,2012,36.0,12.0,Catholic,pretty happy,gemini,"moderate, middle of the road",high school
# 55106,2012,47.0,13.0,Protestant,pretty happy,gemini,conservative,high school
# 55107,2012,55.0,12.0,Catholic,pretty happy,taurus,"moderate, middle of the road",high school
# 55108,2012,18.0,12.0,Catholic,pretty happy,pisces,"moderate, middle of the road",high school
# 55109,2012,76.0,0.0,Catholic,not too happy,leo,extremely conservative,less than high school
# 55110,2012,39.0,10.0,Catholic,pretty happy,taurus,extremely conservative,less than high school
# 55111,2012,54.0,14.0,Protestant,pretty happy,taurus,conservative,associate/junior college
# 55112,2012,45.0,16.0,None,very happy,libra,liberal,associate/junior college
# 55113,2012,71.0,12.0,Protestant,very happy,pisces,slightly conservative,high school
# 55114,2012,42.0,17.0,Orthodox-Christian,pretty happy,scorpio,"moderate, middle of the road",bachelor's
# 55115,2012,22.0,15.0,Protestant,pretty happy,gemini,"moderate, middle of the road",high school
# 55116,2012,50.0,10.0,Catholic,very happy,pisces,"moderate, middle of the road",less than high school
# 55117,2012,81.0,16.0,Catholic,not too happy,sagittarius,"moderate, middle of the road",bachelor's
# 55118,2012,44.0,13.0,Christian,pretty happy,scorpio,conservative,high school
# 55119,2012,78.0,16.0,Catholic,pretty happy,cancer,"moderate, middle of the road",bachelor's
# 55120,2012,63.0,14.0,Catholic,very happy,virgo,liberal,associate/junior college
# 55121,2012,73.0,19.0,None,very happy,cancer,liberal,graduate
# 55122,2012,40.0,16.0,Hinduism,pretty happy,scorpio,slightly liberal,bachelor's
# 55123,2012,42.0,14.0,Catholic,pretty happy,sagittarius,slightly conservative,high school
# 55124,2012,62.0,18.0,Protestant,pretty happy,scorpio,liberal,graduate
# 55125,2012,52.0,11.0,Protestant,pretty happy,aries,,high school
# 55126,2012,49.0,12.0,Protestant,very happy,virgo,"moderate, middle of the road",high school
# 55127,2012,27.0,17.0,None,pretty happy,libra,liberal,bachelor's
# 55128,2012,30.0,14.0,Protestant,pretty happy,gemini,"moderate, middle of the road",high school
# 55129,2012,29.0,18.0,Hinduism,very happy,libra,liberal,graduate
# 55130,2012,69.0,14.0,None,not too happy,virgo,slightly liberal,high school
# 55131,2012,51.0,18.0,Unknown,pretty happy,capricorn,slightly conservative,graduate
# 55132,2012,57.0,16.0,Catholic,very happy,aries,slightly conservative,bachelor's
# 55133,2012,44.0,16.0,Unknown,very happy,cancer,slightly conservative,bachelor's
# 55134,2012,73.0,16.0,Unknown,very happy,capricorn,slightly liberal,bachelor's
# 55135,2012,73.0,16.0,Unknown,pretty happy,gemini,"moderate, middle of the road",bachelor's
# 55136,2012,68.0,16.0,Unknown,very happy,virgo,"moderate, middle of the road",graduate
# 55137,2012,84.0,16.0,Protestant,pretty happy,leo,liberal,bachelor's
# 55138,2012,63.0,19.0,None,very happy,pisces,"moderate, middle of the road",graduate
# 55139,2012,57.0,16.0,Catholic,pretty happy,sagittarius,"moderate, middle of the road",bachelor's
# 55140,2012,42.0,16.0,Catholic,pretty happy,capricorn,slightly conservative,bachelor's
# 55141,2012,45.0,20.0,None,very happy,leo,"moderate, middle of the road",graduate
# 55142,2012,38.0,14.0,None,very happy,aquarius,liberal,associate/junior college
# 55143,2012,46.0,20.0,Unknown,very happy,scorpio,slightly liberal,graduate
# 55144,2012,51.0,20.0,Other,pretty happy,cancer,"moderate, middle of the road",graduate
# 55145,2012,41.0,14.0,Protestant,pretty happy,aquarius,"moderate, middle of the road",high school
# 55146,2012,75.0,12.0,Protestant,not too happy,libra,slightly liberal,high school
# 55147,2012,81.0,8.0,Christian,pretty happy,pisces,slightly conservative,less than high school
# 55148,2012,41.0,9.0,Protestant,very happy,virgo,conservative,less than high school
# 55149,2012,67.0,19.0,Christian,not too happy,,"moderate, middle of the road",graduate
# 55150,2012,71.0,19.0,Protestant,pretty happy,aries,"moderate, middle of the road",graduate
# 55151,2012,35.0,6.0,Islam,pretty happy,,"moderate, middle of the road",less than high school
# 55152,2012,45.0,17.0,Catholic,not too happy,capricorn,"moderate, middle of the road",bachelor's
# 55153,2012,35.0,16.0,Protestant,not too happy,,conservative,bachelor's
# 55154,2012,21.0,14.0,Protestant,not too happy,libra,conservative,high school
# 55155,2012,52.0,11.0,Catholic,pretty happy,cancer,slightly conservative,less than high school
# 55156,2012,49.0,16.0,Protestant,pretty happy,scorpio,slightly liberal,bachelor's
# 55157,2012,46.0,16.0,None,not too happy,sagittarius,extremely liberal,bachelor's
# 55158,2012,51.0,14.0,Catholic,pretty happy,libra,extremely liberal,high school
# 55159,2012,28.0,16.0,None,pretty happy,cancer,slightly liberal,bachelor's
# 55160,2012,81.0,16.0,Protestant,pretty happy,capricorn,liberal,graduate
# 55161,2012,47.0,17.0,Islam,pretty happy,pisces,liberal,bachelor's
# 55162,2012,48.0,14.0,Islam,not too happy,,liberal,associate/junior college
# 55163,2012,46.0,16.0,None,pretty happy,sagittarius,"moderate, middle of the road",bachelor's
# 55164,2012,68.0,12.0,Catholic,not too happy,aquarius,slightly conservative,high school
# 55165,2012,56.0,16.0,Catholic,pretty happy,virgo,slightly liberal,bachelor's
# 55166,2012,43.0,14.0,Catholic,pretty happy,aries,"moderate, middle of the road",high school
# 55167,2012,32.0,13.0,Protestant,very happy,taurus,extremely conservative,high school
# 55168,2012,23.0,12.0,Catholic,not too happy,cancer,"moderate, middle of the road",less than high school
# 55169,2012,59.0,12.0,Unknown,not too happy,libra,slightly conservative,high school
# 55170,2012,32.0,18.0,None,pretty happy,virgo,slightly liberal,graduate
# 55171,2012,44.0,16.0,None,very happy,cancer,liberal,graduate
# 55172,2012,49.0,20.0,None,pretty happy,libra,slightly liberal,graduate
# 55173,2012,64.0,12.0,None,pretty happy,gemini,liberal,high school
# 55174,2012,30.0,19.0,Protestant,very happy,aries,"moderate, middle of the road",graduate
# 55175,2012,51.0,12.0,Catholic,not too happy,virgo,liberal,high school
# 55176,2012,28.0,17.0,None,,aquarius,liberal,bachelor's
# 55177,2012,84.0,13.0,Catholic,very happy,leo,"moderate, middle of the road",high school
# 55178,2012,32.0,14.0,Protestant,very happy,libra,conservative,high school
# 55179,2012,54.0,18.0,Protestant,pretty happy,leo,liberal,graduate
# 55180,2012,34.0,20.0,None,pretty happy,virgo,"moderate, middle of the road",bachelor's
# 55181,2012,33.0,16.0,None,very happy,aries,extremely liberal,graduate
# 55182,2012,48.0,12.0,Catholic,pretty happy,aries,liberal,high school
# 55183,2012,52.0,10.0,Catholic,pretty happy,libra,liberal,less than high school
# 55184,2012,,14.0,Catholic,not too happy,,liberal,high school
# 55185,2012,54.0,16.0,Unknown,very happy,taurus,"moderate, middle of the road",bachelor's
# 55186,2012,19.0,13.0,Other Eastern Religions,pretty happy,scorpio,"moderate, middle of the road",high school
# 55187,2012,41.0,16.0,None,very happy,pisces,"moderate, middle of the road",bachelor's
# 55188,2012,23.0,17.0,Catholic,pretty happy,virgo,liberal,high school
# 55189,2012,51.0,12.0,Islam,not too happy,taurus,conservative,high school
# 55190,2012,75.0,16.0,Protestant,pretty happy,libra,liberal,bachelor's
# 55191,2012,,20.0,Catholic,pretty happy,,conservative,graduate
# 55192,2012,27.0,12.0,Catholic,pretty happy,cancer,slightly liberal,high school
# 55193,2012,24.0,14.0,None,pretty happy,cancer,,high school
# 55194,2012,26.0,20.0,Catholic,pretty happy,libra,slightly conservative,graduate
# 55195,2012,47.0,19.0,Unknown,pretty happy,aquarius,liberal,graduate
# 55196,2012,55.0,13.0,Protestant,pretty happy,leo,conservative,high school
# 55197,2012,55.0,18.0,Protestant,not too happy,sagittarius,"moderate, middle of the road",graduate
# 55198,2012,43.0,17.0,Catholic,pretty happy,leo,liberal,bachelor's
# 55199,2012,46.0,14.0,Protestant,pretty happy,taurus,liberal,high school
# 55200,2012,71.0,16.0,Protestant,pretty happy,aquarius,liberal,bachelor's
# 55201,2012,32.0,16.0,Catholic,pretty happy,aries,"moderate, middle of the road",bachelor's
# 55202,2012,63.0,17.0,Protestant,pretty happy,taurus,"moderate, middle of the road",graduate
# 55203,2012,50.0,12.0,Protestant,pretty happy,scorpio,"moderate, middle of the road",high school
# 55204,2012,60.0,12.0,Protestant,very happy,cancer,slightly conservative,high school
# 55205,2012,33.0,14.0,Catholic,not too happy,pisces,"moderate, middle of the road",associate/junior college
# 55206,2012,40.0,18.0,None,pretty happy,taurus,conservative,graduate
# 55207,2012,68.0,12.0,Catholic,pretty happy,aries,slightly conservative,high school
# 55208,2012,69.0,14.0,Catholic,pretty happy,scorpio,"moderate, middle of the road",associate/junior college
# 55209,2012,71.0,18.0,Orthodox-Christian,pretty happy,leo,"moderate, middle of the road",graduate
# 55210,2012,23.0,15.0,Christian,very happy,aries,"moderate, middle of the road",high school
# 55211,2012,28.0,16.0,None,pretty happy,gemini,"moderate, middle of the road",bachelor's
# 55212,2012,49.0,12.0,Protestant,pretty happy,gemini,slightly conservative,high school
# 55213,2012,66.0,16.0,Catholic,not too happy,scorpio,"moderate, middle of the road",graduate
# 55214,2012,36.0,20.0,Protestant,pretty happy,taurus,liberal,bachelor's
# 55215,2012,53.0,19.0,Catholic,pretty happy,aquarius,liberal,graduate
# 55216,2012,40.0,6.0,Catholic,not too happy,cancer,slightly liberal,less than high school
# 55217,2012,34.0,12.0,Christian,pretty happy,gemini,"moderate, middle of the road",high school
# 55218,2012,58.0,6.0,Catholic,pretty happy,capricorn,"moderate, middle of the road",less than high school
# 55219,2012,62.0,12.0,Catholic,not too happy,scorpio,liberal,high school
# 55220,2012,24.0,12.0,Catholic,not too happy,cancer,extremely conservative,high school
# 55221,2012,72.0,6.0,Protestant,very happy,aries,extremely liberal,less than high school
# 55222,2012,32.0,12.0,Catholic,not too happy,pisces,"moderate, middle of the road",high school
# 55223,2012,29.0,16.0,None,pretty happy,virgo,liberal,bachelor's
# 55224,2012,34.0,12.0,Protestant,not too happy,libra,liberal,high school
# 55225,2012,36.0,13.0,Protestant,pretty happy,scorpio,"moderate, middle of the road",high school
# 55226,2012,74.0,8.0,Protestant,pretty happy,gemini,slightly conservative,less than high school
# 55227,2012,49.0,16.0,None,pretty happy,pisces,conservative,bachelor's
# 55228,2012,60.0,16.0,None,pretty happy,capricorn,extremely liberal,bachelor's
# 55229,2012,78.0,16.0,Protestant,not too happy,leo,extremely conservative,bachelor's
# 55230,2012,39.0,14.0,Christian,pretty happy,aries,"moderate, middle of the road",high school
# 55231,2012,73.0,16.0,Protestant,not too happy,taurus,"moderate, middle of the road",bachelor's
# 55232,2012,67.0,16.0,Christian,pretty happy,cancer,slightly conservative,associate/junior college
# 55233,2012,82.0,11.0,Catholic,not too happy,libra,conservative,less than high school
# 55234,2012,64.0,14.0,Catholic,pretty happy,,liberal,high school
# 55235,2012,61.0,14.0,Catholic,pretty happy,taurus,conservative,high school
# 55236,2012,22.0,6.0,None,not too happy,capricorn,liberal,less than high school
# 55237,2012,27.0,14.0,Catholic,pretty happy,sagittarius,"moderate, middle of the road",associate/junior college
# 55238,2012,41.0,14.0,Catholic,pretty happy,aquarius,"moderate, middle of the road",high school
# 55239,2012,33.0,9.0,None,not too happy,aquarius,conservative,less than high school
# 55240,2012,49.0,6.0,Catholic,pretty happy,cancer,liberal,less than high school
# 55241,2012,22.0,11.0,Catholic,pretty happy,virgo,liberal,less than high school
# 55242,2012,42.0,6.0,Catholic,very happy,pisces,conservative,less than high school
# 55243,2012,28.0,11.0,Catholic,pretty happy,scorpio,"moderate, middle of the road",less than high school
# 55244,2012,66.0,14.0,Protestant,very happy,leo,"moderate, middle of the road",high school
# 55245,2012,35.0,13.0,None,not too happy,virgo,extremely liberal,high school
# 55246,2012,52.0,12.0,Catholic,pretty happy,,"moderate, middle of the road",high school
# 55247,2012,63.0,14.0,Other,pretty happy,capricorn,conservative,high school
# 55248,2012,31.0,13.0,None,very happy,scorpio,"moderate, middle of the road",high school
# 55249,2012,29.0,17.0,Islam,very happy,capricorn,liberal,bachelor's
# 55250,2012,50.0,17.0,Protestant,very happy,virgo,"moderate, middle of the road",bachelor's
# 55251,2012,47.0,12.0,Catholic,pretty happy,aquarius,slightly conservative,high school
# 55252,2012,65.0,12.0,Protestant,pretty happy,aquarius,liberal,high school
# 55253,2012,62.0,13.0,Unknown,pretty happy,virgo,slightly conservative,high school
# 55254,2012,18.0,13.0,Unknown,pretty happy,cancer,liberal,high school
# 55255,2012,40.0,14.0,None,not too happy,sagittarius,extremely liberal,high school
# 55256,2012,28.0,16.0,Catholic,pretty happy,,"moderate, middle of the road",bachelor's
# 55257,2012,24.0,16.0,Catholic,pretty happy,aquarius,"moderate, middle of the road",bachelor's
# 55258,2012,40.0,16.0,Protestant,pretty happy,cancer,"moderate, middle of the road",graduate
# 55259,2012,77.0,15.0,Protestant,very happy,libra,liberal,bachelor's
# 55260,2012,24.0,15.0,None,very happy,aquarius,slightly liberal,associate/junior college
# 55261,2012,21.0,14.0,None,pretty happy,cancer,"moderate, middle of the road",high school
# 55262,2012,22.0,15.0,Protestant,very happy,libra,slightly conservative,high school
# 55263,2012,24.0,16.0,Catholic,very happy,sagittarius,"moderate, middle of the road",associate/junior college
# 55264,2012,22.0,11.0,Catholic,very happy,leo,,high school
# 55265,2012,21.0,15.0,None,very happy,leo,slightly conservative,high school
# 55266,2012,67.0,16.0,Protestant,pretty happy,libra,liberal,graduate
# 55267,2012,32.0,19.0,Christian,very happy,virgo,conservative,bachelor's
# 55268,2012,38.0,9.0,Catholic,pretty happy,pisces,extremely conservative,less than high school
# 55269,2012,55.0,12.0,Catholic,pretty happy,virgo,conservative,high school
# 55270,2012,40.0,14.0,Catholic,not too happy,gemini,"moderate, middle of the road",high school
# 55271,2012,38.0,11.0,Protestant,very happy,sagittarius,conservative,high school
# 55272,2012,52.0,13.0,Other Eastern Religions,pretty happy,,"moderate, middle of the road",high school
# 55273,2012,34.0,16.0,Protestant,pretty happy,pisces,"moderate, middle of the road",bachelor's
# 55274,2012,22.0,16.0,Protestant,pretty happy,aquarius,slightly liberal,bachelor's
# 55275,2012,56.0,17.0,None,very happy,cancer,"moderate, middle of the road",bachelor's
# 55276,2012,60.0,12.0,Catholic,pretty happy,aquarius,slightly conservative,high school
# 55277,2012,39.0,16.0,Catholic,very happy,leo,slightly conservative,bachelor's
# 55278,2012,33.0,16.0,Protestant,pretty happy,aries,slightly conservative,bachelor's
# 55279,2012,67.0,12.0,Protestant,pretty happy,taurus,"moderate, middle of the road",high school
# 55280,2012,51.0,12.0,None,pretty happy,sagittarius,slightly conservative,high school
# 55281,2012,65.0,12.0,None,not too happy,capricorn,liberal,high school
# 55282,2012,42.0,16.0,None,pretty happy,aquarius,slightly conservative,bachelor's
# 55283,2012,65.0,12.0,Catholic,not too happy,capricorn,"moderate, middle of the road",high school
# 55284,2012,25.0,13.0,Protestant,very happy,libra,"moderate, middle of the road",high school
# 55285,2012,36.0,12.0,Protestant,pretty happy,cancer,slightly conservative,high school
# 55286,2012,38.0,14.0,Protestant,very happy,taurus,liberal,high school
# 55287,2012,18.0,12.0,Christian,pretty happy,cancer,slightly liberal,high school
# 55288,2012,38.0,9.0,Catholic,very happy,libra,extremely liberal,less than high school
# 55289,2012,41.0,9.0,Catholic,very happy,taurus,slightly liberal,less than high school
# 55290,2012,20.0,14.0,None,pretty happy,aries,liberal,high school
# 55291,2012,39.0,16.0,None,pretty happy,capricorn,extremely liberal,bachelor's
# 55292,2012,25.0,17.0,Catholic,pretty happy,gemini,slightly conservative,bachelor's
# 55293,2012,57.0,14.0,Catholic,pretty happy,scorpio,slightly conservative,associate/junior college
# 55294,2012,61.0,13.0,Protestant,pretty happy,cancer,liberal,less than high school
# 55295,2012,31.0,16.0,Catholic,pretty happy,leo,slightly liberal,bachelor's
# 55296,2012,62.0,19.0,Protestant,pretty happy,,slightly conservative,graduate
# 55297,2012,30.0,12.0,None,very happy,pisces,liberal,high school
# 55298,2012,68.0,14.0,Protestant,very happy,aquarius,extremely conservative,associate/junior college
# 55299,2012,50.0,16.0,Catholic,pretty happy,libra,"moderate, middle of the road",high school
# 55300,2012,27.0,12.0,Protestant,pretty happy,aquarius,extremely liberal,high school
# 55301,2012,30.0,16.0,Protestant,pretty happy,sagittarius,liberal,bachelor's
# 55302,2012,65.0,14.0,Catholic,pretty happy,gemini,conservative,associate/junior college
# 55303,2012,65.0,18.0,Catholic,pretty happy,gemini,slightly liberal,graduate
# 55304,2012,36.0,19.0,None,pretty happy,virgo,liberal,graduate
# 55305,2012,72.0,12.0,Protestant,not too happy,capricorn,conservative,high school
# 55306,2012,27.0,12.0,Catholic,pretty happy,gemini,slightly liberal,high school
# 55307,2012,22.0,12.0,Catholic,very happy,virgo,liberal,high school
# 55308,2012,33.0,9.0,Catholic,pretty happy,leo,"moderate, middle of the road",less than high school
# 55309,2012,35.0,6.0,Catholic,pretty happy,taurus,slightly conservative,less than high school
# 55310,2012,54.0,11.0,Protestant,very happy,libra,slightly liberal,less than high school
# 55311,2012,18.0,11.0,None,very happy,,"moderate, middle of the road",less than high school
# 55312,2012,38.0,12.0,Protestant,pretty happy,taurus,"moderate, middle of the road",high school
# 55313,2012,67.0,12.0,Protestant,pretty happy,scorpio,conservative,high school
# 55314,2012,48.0,12.0,Protestant,pretty happy,gemini,"moderate, middle of the road",high school
# 55315,2012,64.0,19.0,None,pretty happy,aries,liberal,graduate
# 55316,2012,89.0,19.0,Protestant,pretty happy,cancer,"moderate, middle of the road",graduate
# 55317,2012,48.0,12.0,Catholic,very happy,pisces,slightly conservative,high school
# 55318,2012,44.0,6.0,Catholic,very happy,libra,"moderate, middle of the road",less than high school
# 55319,2012,42.0,15.0,Catholic,pretty happy,virgo,"moderate, middle of the road",high school
# 55320,2012,26.0,16.0,Protestant,very happy,gemini,"moderate, middle of the road",bachelor's
# 55321,2012,68.0,12.0,Protestant,very happy,aries,slightly conservative,less than high school
# 55322,2012,61.0,14.0,Protestant,very happy,libra,slightly liberal,high school
# 55323,2012,34.0,13.0,None,very happy,aquarius,"moderate, middle of the road",high school
# 55324,2012,35.0,6.0,Catholic,very happy,scorpio,"moderate, middle of the road",less than high school
# 55325,2012,53.0,17.0,Christian,pretty happy,,slightly conservative,bachelor's
# 55326,2012,32.0,12.0,Catholic,very happy,leo,"moderate, middle of the road",high school
# 55327,2012,61.0,14.0,Catholic,pretty happy,sagittarius,slightly conservative,high school
# 55328,2012,28.0,10.0,Catholic,pretty happy,pisces,"moderate, middle of the road",high school
# 55329,2012,39.0,12.0,Catholic,very happy,pisces,slightly liberal,high school
# 55330,2012,61.0,16.0,Catholic,very happy,gemini,slightly conservative,bachelor's
# 55331,2012,65.0,18.0,Catholic,pretty happy,aquarius,conservative,graduate
# 55332,2012,34.0,18.0,Protestant,very happy,taurus,slightly conservative,graduate
# 55333,2012,87.0,12.0,Catholic,pretty happy,gemini,slightly liberal,high school
# 55334,2012,24.0,16.0,Other,pretty happy,scorpio,"moderate, middle of the road",high school
# 55335,2012,39.0,12.0,Christian,pretty happy,leo,extremely liberal,high school
# 55336,2012,76.0,0.0,Protestant,pretty happy,aquarius,,less than high school
# 55337,2012,32.0,14.0,Protestant,not too happy,aries,conservative,associate/junior college
# 55338,2012,54.0,16.0,Protestant,pretty happy,scorpio,"moderate, middle of the road",bachelor's
# 55339,2012,55.0,14.0,Christian,not too happy,scorpio,"moderate, middle of the road",associate/junior college
# 55340,2012,53.0,16.0,Protestant,pretty happy,aquarius,"moderate, middle of the road",bachelor's
# 55341,2012,62.0,14.0,Protestant,pretty happy,aries,"moderate, middle of the road",high school
# 55342,2012,39.0,6.0,Catholic,not too happy,sagittarius,slightly conservative,less than high school
# 55343,2012,30.0,12.0,Catholic,pretty happy,capricorn,"moderate, middle of the road",high school
# 55344,2012,89.0,8.0,Protestant,pretty happy,leo,extremely liberal,less than high school
# 55345,2012,30.0,10.0,None,very happy,,extremely liberal,high school
# 55346,2012,35.0,12.0,Catholic,very happy,virgo,slightly liberal,high school
# 55347,2012,73.0,16.0,Catholic,very happy,cancer,"moderate, middle of the road",bachelor's
# 55348,2012,69.0,16.0,Protestant,pretty happy,aquarius,slightly conservative,bachelor's
# 55349,2012,89.0,12.0,Protestant,pretty happy,taurus,conservative,high school
# 55350,2012,55.0,16.0,Protestant,very happy,taurus,"moderate, middle of the road",bachelor's
# 55351,2012,78.0,12.0,Catholic,pretty happy,virgo,"moderate, middle of the road",high school
# 55352,2012,43.0,17.0,Protestant,pretty happy,virgo,"moderate, middle of the road",bachelor's
# 55353,2012,68.0,16.0,Protestant,very happy,scorpio,conservative,bachelor's
# 55354,2012,71.0,16.0,Protestant,very happy,cancer,conservative,bachelor's
# 55355,2012,47.0,16.0,Protestant,very happy,pisces,slightly conservative,bachelor's
# 55356,2012,68.0,18.0,Protestant,pretty happy,taurus,slightly liberal,graduate
# 55357,2012,76.0,12.0,Protestant,pretty happy,taurus,"moderate, middle of the road",high school
# 55358,2012,55.0,16.0,Catholic,very happy,capricorn,slightly conservative,bachelor's
# 55359,2012,49.0,12.0,Christian,very happy,taurus,conservative,high school
# 55360,2012,68.0,14.0,Protestant,pretty happy,leo,slightly conservative,high school
# 55361,2012,47.0,11.0,Other,very happy,capricorn,conservative,less than high school
# 55362,2012,59.0,14.0,None,very happy,leo,liberal,associate/junior college
# 55363,2012,74.0,16.0,Protestant,pretty happy,capricorn,,bachelor's
# 55364,2012,71.0,14.0,Protestant,pretty happy,scorpio,"moderate, middle of the road",associate/junior college
# 55365,2012,32.0,12.0,Catholic,pretty happy,scorpio,slightly conservative,high school
# 55366,2012,30.0,16.0,Protestant,very happy,libra,conservative,bachelor's
# 55367,2012,38.0,16.0,None,very happy,scorpio,slightly conservative,graduate
# 55368,2012,41.0,16.0,None,pretty happy,gemini,"moderate, middle of the road",bachelor's
# 55369,2012,62.0,20.0,Protestant,very happy,sagittarius,"moderate, middle of the road",graduate
# 55370,2012,49.0,20.0,Protestant,pretty happy,cancer,"moderate, middle of the road",graduate
# 55371,2012,52.0,16.0,Protestant,pretty happy,cancer,slightly liberal,associate/junior college
# 55372,2012,61.0,13.0,Catholic,not too happy,virgo,slightly conservative,high school
# 55373,2012,52.0,16.0,None,pretty happy,sagittarius,liberal,bachelor's
# 55374,2012,33.0,14.0,Catholic,pretty happy,capricorn,conservative,associate/junior college
# 55375,2012,65.0,16.0,Unknown,pretty happy,leo,conservative,bachelor's
# 55376,2012,55.0,12.0,None,not too happy,aquarius,conservative,less than high school
# 55377,2012,45.0,14.0,Protestant,very happy,,"moderate, middle of the road",associate/junior college
# 55378,2012,35.0,9.0,Catholic,pretty happy,aries,"moderate, middle of the road",less than high school
# 55379,2012,36.0,14.0,Protestant,pretty happy,leo,extremely liberal,associate/junior college
# 55380,2012,43.0,16.0,Protestant,very happy,aquarius,"moderate, middle of the road",graduate
# 55381,2012,83.0,13.0,Catholic,not too happy,scorpio,liberal,high school
# 55382,2012,64.0,14.0,Protestant,not too happy,aries,"moderate, middle of the road",high school
# 55383,2012,38.0,18.0,None,pretty happy,leo,slightly liberal,graduate
# 55384,2012,25.0,14.0,Protestant,pretty happy,capricorn,slightly conservative,high school
# 55385,2012,81.0,18.0,Protestant,not too happy,cancer,conservative,graduate
# 55386,2012,23.0,12.0,None,not too happy,aquarius,,high school
# 55387,2012,21.0,12.0,Catholic,not too happy,cancer,"moderate, middle of the road",high school
# 55388,2012,56.0,12.0,Catholic,pretty happy,gemini,"moderate, middle of the road",high school
# 55389,2012,30.0,11.0,Protestant,pretty happy,cancer,"moderate, middle of the road",high school
# 55390,2012,69.0,12.0,Protestant,not too happy,capricorn,"moderate, middle of the road",high school
# 55391,2012,62.0,12.0,Catholic,pretty happy,libra,extremely conservative,high school
# 55392,2012,39.0,16.0,Catholic,pretty happy,sagittarius,"moderate, middle of the road",bachelor's
# 55393,2012,25.0,18.0,None,not too happy,taurus,liberal,bachelor's
# 55394,2012,75.0,20.0,Protestant,not too happy,capricorn,liberal,graduate
# 55395,2012,46.0,18.0,None,pretty happy,libra,"moderate, middle of the road",graduate
# 55396,2012,57.0,6.0,Islam,not too happy,cancer,slightly liberal,less than high school
# 55397,2012,20.0,13.0,Protestant,pretty happy,aquarius,slightly conservative,high school
# 55398,2012,53.0,16.0,Protestant,pretty happy,pisces,"moderate, middle of the road",bachelor's
# 55399,2012,53.0,16.0,Protestant,pretty happy,leo,conservative,bachelor's
# 55400,2012,42.0,8.0,Protestant,very happy,pisces,extremely liberal,less than high school
# 55401,2012,63.0,18.0,Protestant,very happy,aries,"moderate, middle of the road",graduate
# 55402,2012,55.0,20.0,None,pretty happy,virgo,liberal,graduate
# 55403,2012,54.0,17.0,Protestant,very happy,libra,slightly conservative,graduate
# 55404,2012,77.0,20.0,Protestant,very happy,taurus,slightly conservative,graduate
# 55405,2012,48.0,16.0,None,,capricorn,"moderate, middle of the road",bachelor's
# 55406,2012,52.0,4.0,Protestant,pretty happy,,,less than high school
# 55407,2012,31.0,13.0,Protestant,pretty happy,pisces,slightly conservative,high school
# 55408,2012,57.0,12.0,Protestant,pretty happy,aries,,high school
# 55409,2012,21.0,12.0,None,not too happy,aquarius,slightly liberal,high school
# 55410,2012,50.0,15.0,Protestant,pretty happy,scorpio,slightly conservative,associate/junior college
# 55411,2012,38.0,16.0,Protestant,very happy,leo,"moderate, middle of the road",bachelor's
# 55412,2012,33.0,12.0,Unknown,very happy,gemini,,less than high school
# 55413,2012,26.0,14.0,Protestant,very happy,aries,"moderate, middle of the road",high school
# 55414,2012,33.0,14.0,None,not too happy,gemini,liberal,high school
# 55415,2012,44.0,17.0,Protestant,pretty happy,sagittarius,slightly liberal,bachelor's
# 55416,2012,25.0,16.0,Protestant,pretty happy,libra,conservative,bachelor's
# 55417,2012,27.0,16.0,None,pretty happy,taurus,"moderate, middle of the road",bachelor's
# 55418,2012,27.0,16.0,Catholic,very happy,capricorn,"moderate, middle of the road",bachelor's
# 55419,2012,28.0,16.0,None,very happy,scorpio,slightly liberal,bachelor's
# 55420,2012,22.0,16.0,Catholic,very happy,virgo,liberal,bachelor's
# 55421,2012,48.0,17.0,Catholic,pretty happy,aries,liberal,graduate
# 55422,2012,89.0,8.0,Catholic,not too happy,gemini,conservative,less than high school
# 55423,2012,49.0,17.0,Catholic,pretty happy,cancer,conservative,bachelor's
# 55424,2012,87.0,12.0,Catholic,pretty happy,taurus,liberal,high school
# 55425,2012,64.0,17.0,None,pretty happy,aries,"moderate, middle of the road",bachelor's
# 55426,2012,41.0,15.0,Protestant,pretty happy,sagittarius,conservative,associate/junior college
# 55427,2012,57.0,9.0,Catholic,not too happy,capricorn,liberal,less than high school
# 55428,2012,46.0,16.0,Catholic,pretty happy,,"moderate, middle of the road",bachelor's
# 55429,2012,58.0,16.0,Unknown,pretty happy,aries,liberal,graduate
# 55430,2012,78.0,16.0,Protestant,very happy,libra,slightly liberal,bachelor's
# 55431,2012,45.0,19.0,Catholic,pretty happy,,slightly liberal,graduate
# 55432,2012,38.0,14.0,Catholic,pretty happy,taurus,liberal,high school
# 55433,2012,69.0,20.0,Protestant,not too happy,gemini,liberal,graduate
# 55434,2012,61.0,16.0,Catholic,very happy,libra,liberal,associate/junior college
# 55435,2012,48.0,16.0,None,pretty happy,gemini,extremely liberal,graduate
# 55436,2012,37.0,16.0,Catholic,pretty happy,taurus,conservative,bachelor's
# 55437,2012,47.0,12.0,None,pretty happy,pisces,slightly liberal,high school
# 55438,2012,26.0,18.0,None,pretty happy,sagittarius,"moderate, middle of the road",graduate
# 55439,2012,41.0,13.0,Catholic,pretty happy,cancer,slightly liberal,high school
# 55440,2012,55.0,18.0,Buddhism,not too happy,aries,extremely liberal,graduate
# 55441,2012,81.0,10.0,Catholic,very happy,capricorn,extremely liberal,less than high school
# 55442,2012,32.0,17.0,None,pretty happy,capricorn,slightly liberal,bachelor's
# 55443,2012,27.0,14.0,Other,very happy,taurus,slightly conservative,high school
# 55444,2012,32.0,13.0,Protestant,pretty happy,leo,"moderate, middle of the road",high school
# 55445,2012,39.0,18.0,Protestant,pretty happy,virgo,slightly conservative,graduate
# 55446,2012,55.0,16.0,Catholic,pretty happy,aquarius,"moderate, middle of the road",bachelor's
# 55447,2012,35.0,16.0,None,pretty happy,cancer,"moderate, middle of the road",bachelor's
# 55448,2012,64.0,17.0,None,very happy,capricorn,extremely liberal,bachelor's
# 55449,2012,85.0,15.0,Protestant,pretty happy,pisces,"moderate, middle of the road",high school
# 55450,2012,52.0,12.0,Catholic,pretty happy,sagittarius,"moderate, middle of the road",high school
# 55451,2012,46.0,12.0,Catholic,pretty happy,aquarius,slightly liberal,high school
# 55452,2012,34.0,5.0,Protestant,not too happy,scorpio,slightly liberal,less than high school
# 55453,2012,55.0,10.0,Catholic,pretty happy,aquarius,"moderate, middle of the road",less than high school
# 55454,2012,72.0,12.0,Catholic,pretty happy,scorpio,slightly conservative,high school
# 55455,2012,34.0,16.0,None,pretty happy,aries,"moderate, middle of the road",associate/junior college
# 55456,2012,35.0,10.0,Catholic,pretty happy,libra,conservative,less than high school
# 55457,2012,61.0,12.0,Protestant,pretty happy,virgo,slightly conservative,high school
# 55458,2012,56.0,12.0,Catholic,pretty happy,scorpio,"moderate, middle of the road",high school
# 55459,2012,60.0,15.0,Catholic,pretty happy,aries,liberal,high school
# 55460,2012,65.0,16.0,Protestant,pretty happy,sagittarius,slightly liberal,bachelor's
# 55461,2012,85.0,9.0,Protestant,very happy,pisces,,high school
# 55462,2012,42.0,12.0,Catholic,pretty happy,capricorn,extremely liberal,high school
# 55463,2012,27.0,14.0,Catholic,very happy,virgo,liberal,high school
# 55464,2012,85.0,12.0,Protestant,pretty happy,gemini,liberal,high school
# 55465,2012,63.0,14.0,Catholic,pretty happy,libra,liberal,high school
# 55466,2012,61.0,15.0,None,pretty happy,aries,liberal,bachelor's
# 55467,2012,27.0,20.0,None,pretty happy,gemini,"moderate, middle of the road",graduate
# 55468,2012,48.0,16.0,None,not too happy,libra,slightly liberal,bachelor's
# 55469,2012,25.0,16.0,None,very happy,sagittarius,"moderate, middle of the road",bachelor's
# 55470,2012,34.0,13.0,Buddhism,very happy,taurus,slightly conservative,high school
# 55471,2012,37.0,16.0,None,not too happy,,conservative,bachelor's
# 55472,2012,64.0,14.0,Protestant,not too happy,aries,"moderate, middle of the road",high school
# 55473,2012,82.0,18.0,Unknown,pretty happy,cancer,slightly liberal,graduate
# 55474,2012,43.0,16.0,None,pretty happy,aries,slightly liberal,bachelor's
# 55475,2012,54.0,14.0,None,not too happy,libra,extremely liberal,high school
# 55476,2012,25.0,18.0,Catholic,pretty happy,virgo,slightly liberal,high school
# 55477,2012,78.0,17.0,Protestant,pretty happy,capricorn,liberal,bachelor's
# 55478,2012,19.0,12.0,Protestant,pretty happy,taurus,conservative,high school
# 55479,2012,64.0,11.0,None,pretty happy,leo,extremely liberal,high school
# 55480,2012,23.0,13.0,None,pretty happy,libra,"moderate, middle of the road",high school
# 55481,2012,31.0,16.0,None,pretty happy,taurus,liberal,bachelor's
# 55482,2012,41.0,15.0,None,very happy,leo,"moderate, middle of the road",associate/junior college
# 55483,2012,29.0,12.0,Protestant,pretty happy,virgo,slightly liberal,high school
# 55484,2012,51.0,19.0,None,very happy,capricorn,slightly liberal,graduate
# 55485,2012,55.0,18.0,Other,pretty happy,pisces,conservative,bachelor's
# 55486,2012,36.0,15.0,Christian,not too happy,leo,slightly liberal,high school
# 55487,2012,87.0,13.0,Catholic,pretty happy,aries,"moderate, middle of the road",high school
# 55488,2012,28.0,17.0,Orthodox-Christian,pretty happy,virgo,"moderate, middle of the road",bachelor's
# 55489,2012,35.0,17.0,Protestant,pretty happy,sagittarius,conservative,bachelor's
# 55490,2012,37.0,18.0,Protestant,very happy,taurus,"moderate, middle of the road",graduate
# 55491,2012,84.0,12.0,Catholic,pretty happy,leo,"moderate, middle of the road",high school
# 55492,2012,21.0,13.0,None,very happy,capricorn,"moderate, middle of the road",high school
# 55493,2012,49.0,17.0,Catholic,pretty happy,taurus,slightly conservative,bachelor's
# 55494,2012,42.0,12.0,Hinduism,very happy,taurus,,high school
# 55495,2012,69.0,14.0,Protestant,pretty happy,gemini,"moderate, middle of the road",high school
# 55496,2012,32.0,16.0,Catholic,very happy,taurus,"moderate, middle of the road",bachelor's
# 55497,2012,69.0,20.0,Protestant,pretty happy,scorpio,liberal,graduate
# 55498,2012,48.0,16.0,Protestant,pretty happy,gemini,extremely liberal,bachelor's
# 55499,2012,20.0,10.0,Catholic,pretty happy,taurus,slightly conservative,less than high school
# 55500,2012,51.0,19.0,None,very happy,,slightly liberal,graduate
# 55501,2012,60.0,20.0,Catholic,pretty happy,pisces,liberal,graduate
# 55502,2012,59.0,16.0,None,pretty happy,virgo,liberal,bachelor's
# 55503,2012,89.0,16.0,Catholic,not too happy,aries,"moderate, middle of the road",bachelor's
# 55504,2012,18.0,12.0,Catholic,pretty happy,pisces,"moderate, middle of the road",high school
# 55505,2012,62.0,20.0,Protestant,very happy,pisces,conservative,bachelor's
# 55506,2012,54.0,13.0,Protestant,pretty happy,libra,slightly conservative,high school
# 55507,2012,19.0,12.0,None,pretty happy,libra,slightly liberal,high school
# 55508,2012,38.0,10.0,Protestant,pretty happy,virgo,slightly conservative,high school
# 55509,2012,31.0,14.0,Protestant,very happy,scorpio,conservative,high school
# 55510,2012,51.0,18.0,Christian,pretty happy,virgo,slightly conservative,graduate
# 55511,2012,23.0,11.0,Inter-Nondenominational,pretty happy,aquarius,slightly liberal,high school
# 55512,2012,48.0,16.0,None,pretty happy,scorpio,liberal,bachelor's
# 55513,2012,45.0,16.0,Catholic,pretty happy,aries,extremely liberal,associate/junior college
# 55514,2012,20.0,12.0,None,pretty happy,aries,"moderate, middle of the road",high school
# 55515,2012,70.0,15.0,Protestant,pretty happy,leo,slightly conservative,high school
# 55516,2012,58.0,16.0,Protestant,very happy,leo,"moderate, middle of the road",bachelor's
# 55517,2012,63.0,16.0,Protestant,,virgo,extremely conservative,bachelor's
# 55518,2012,44.0,12.0,Unknown,very happy,taurus,slightly conservative,high school
# 55519,2012,87.0,14.0,Protestant,very happy,libra,conservative,high school
# 55520,2012,50.0,16.0,Protestant,very happy,gemini,slightly liberal,bachelor's
# 55521,2012,52.0,11.0,Protestant,very happy,pisces,slightly liberal,high school
# 55522,2012,32.0,14.0,Other,very happy,pisces,conservative,associate/junior college
# 55523,2012,43.0,20.0,Unknown,pretty happy,sagittarius,slightly liberal,graduate
# 55524,2012,51.0,16.0,Catholic,very happy,leo,"moderate, middle of the road",bachelor's
# 55525,2012,58.0,20.0,None,pretty happy,capricorn,conservative,graduate
# 55526,2012,75.0,11.0,Protestant,pretty happy,leo,slightly conservative,less than high school
# 55527,2012,71.0,16.0,Protestant,very happy,sagittarius,extremely conservative,bachelor's
# 55528,2012,72.0,14.0,Protestant,not too happy,libra,slightly conservative,high school
# 55529,2012,64.0,14.0,Christian,very happy,libra,conservative,high school
# 55530,2012,35.0,12.0,Protestant,not too happy,capricorn,liberal,high school
# 55531,2012,34.0,15.0,Protestant,not too happy,pisces,"moderate, middle of the road",high school
# 55532,2012,71.0,11.0,None,very happy,libra,slightly conservative,less than high school
# 55533,2012,41.0,17.0,Catholic,pretty happy,scorpio,liberal,bachelor's
# 55534,2012,34.0,13.0,Protestant,pretty happy,libra,extremely conservative,high school
# 55535,2012,50.0,13.0,Protestant,pretty happy,aquarius,slightly conservative,high school
# 55536,2012,23.0,12.0,None,pretty happy,capricorn,slightly liberal,high school
# 55537,2012,53.0,12.0,Protestant,very happy,sagittarius,"moderate, middle of the road",high school
# 55538,2012,64.0,13.0,Protestant,pretty happy,sagittarius,slightly conservative,high school
# 55539,2012,41.0,20.0,Unknown,pretty happy,pisces,liberal,graduate
# 55540,2012,46.0,14.0,None,pretty happy,sagittarius,"moderate, middle of the road",high school
# 55541,2012,54.0,16.0,None,not too happy,libra,liberal,bachelor's
# 55542,2012,67.0,19.0,Protestant,very happy,cancer,extremely liberal,graduate
# 55543,2012,53.0,16.0,Inter-Nondenominational,not too happy,taurus,extremely liberal,bachelor's
# 55544,2012,59.0,12.0,None,very happy,,slightly liberal,high school
# 55545,2012,65.0,12.0,Protestant,very happy,,"moderate, middle of the road",high school
# 55546,2012,51.0,14.0,Catholic,very happy,leo,"moderate, middle of the road",high school
# 55547,2012,39.0,14.0,Catholic,pretty happy,aries,slightly conservative,associate/junior college
# 55548,2012,49.0,12.0,Catholic,pretty happy,leo,conservative,high school
# 55549,2012,30.0,16.0,None,very happy,virgo,liberal,bachelor's
# 55550,2012,57.0,19.0,Protestant,pretty happy,libra,"moderate, middle of the road",bachelor's
# 55551,2012,36.0,18.0,None,pretty happy,gemini,liberal,graduate
# 55552,2012,39.0,18.0,Catholic,very happy,aquarius,"moderate, middle of the road",graduate
# 55553,2012,38.0,18.0,Other Eastern Religions,pretty happy,virgo,"moderate, middle of the road",bachelor's
# 55554,2012,46.0,16.0,None,pretty happy,capricorn,"moderate, middle of the road",bachelor's
# 55555,2012,41.0,18.0,None,pretty happy,sagittarius,slightly liberal,bachelor's
# 55556,2012,29.0,18.0,Hinduism,pretty happy,libra,extremely liberal,graduate
# 55557,2012,58.0,12.0,None,pretty happy,gemini,"moderate, middle of the road",high school
# 55558,2012,48.0,17.0,Protestant,pretty happy,virgo,"moderate, middle of the road",graduate
# 55559,2012,31.0,20.0,Protestant,very happy,,"moderate, middle of the road",graduate
# 55560,2012,54.0,14.0,Protestant,not too happy,aries,slightly liberal,associate/junior college
# 55561,2012,37.0,9.0,Protestant,pretty happy,aries,liberal,less than high school
# 55562,2012,48.0,18.0,Protestant,pretty happy,capricorn,"moderate, middle of the road",graduate
# 55563,2012,58.0,12.0,Protestant,pretty happy,aries,conservative,high school
# 55564,2012,77.0,9.0,None,pretty happy,capricorn,conservative,less than high school
# 55565,2012,44.0,14.0,Protestant,pretty happy,taurus,"moderate, middle of the road",high school
# 55566,2012,27.0,16.0,None,not too happy,capricorn,,associate/junior college
# 55567,2012,19.0,11.0,Catholic,pretty happy,sagittarius,,less than high school
# 55568,2012,55.0,13.0,Protestant,pretty happy,leo,slightly conservative,high school
# 55569,2012,52.0,12.0,Protestant,pretty happy,virgo,conservative,high school
# 55570,2012,63.0,13.0,None,pretty happy,sagittarius,liberal,high school
# 55571,2012,39.0,14.0,Protestant,pretty happy,leo,conservative,associate/junior college
# 55572,2012,68.0,10.0,Protestant,very happy,taurus,,less than high school
# 55573,2012,82.0,4.0,Orthodox-Christian,not too happy,libra,,less than high school
# 55574,2012,59.0,12.0,Christian,pretty happy,libra,conservative,high school
# 55575,2012,64.0,15.0,None,very happy,libra,liberal,high school
# 55576,2012,47.0,18.0,Catholic,not too happy,cancer,"moderate, middle of the road",graduate
# 55577,2012,45.0,12.0,Catholic,pretty happy,sagittarius,slightly liberal,high school
# 55578,2012,37.0,12.0,None,not too happy,aries,conservative,high school
# 55579,2012,20.0,11.0,None,not too happy,cancer,"moderate, middle of the road",less than high school
# 55580,2012,31.0,20.0,Protestant,pretty happy,taurus,"moderate, middle of the road",graduate
# 55581,2012,22.0,13.0,Other,pretty happy,taurus,"moderate, middle of the road",high school
# 55582,2012,61.0,16.0,Catholic,pretty happy,capricorn,slightly conservative,bachelor's
# 55583,2012,56.0,15.0,Protestant,very happy,cancer,conservative,associate/junior college
# 55584,2012,34.0,8.0,None,pretty happy,capricorn,"moderate, middle of the road",less than high school
# 55585,2012,53.0,12.0,Catholic,pretty happy,gemini,liberal,less than high school
# 55586,2012,22.0,12.0,Catholic,pretty happy,libra,extremely liberal,high school
# 55587,2012,39.0,12.0,Catholic,very happy,cancer,extremely conservative,high school
# 55588,2012,25.0,6.0,Catholic,very happy,scorpio,conservative,less than high school
# 55589,2012,75.0,17.0,Catholic,very happy,taurus,conservative,graduate
# 55590,2012,44.0,18.0,None,pretty happy,leo,liberal,graduate
# 55591,2012,26.0,14.0,None,pretty happy,aquarius,"moderate, middle of the road",high school
# 55592,2012,40.0,13.0,Catholic,very happy,taurus,"moderate, middle of the road",associate/junior college
# 55593,2012,33.0,10.0,Catholic,pretty happy,aries,"moderate, middle of the road",high school
# 55594,2012,49.0,12.0,Catholic,pretty happy,libra,slightly conservative,less than high school
# 55595,2012,49.0,12.0,None,very happy,gemini,conservative,high school
# 55596,2012,48.0,20.0,None,pretty happy,sagittarius,extremely liberal,graduate
# 55597,2012,40.0,17.0,None,pretty happy,sagittarius,liberal,bachelor's
# 55598,2012,80.0,14.0,Protestant,pretty happy,virgo,"moderate, middle of the road",high school
# 55599,2012,21.0,12.0,None,very happy,leo,"moderate, middle of the road",high school
# 55600,2012,38.0,0.0,Islam,very happy,,,less than high school
# 55601,2012,74.0,12.0,Protestant,pretty happy,virgo,conservative,high school
# 55602,2012,75.0,16.0,Protestant,pretty happy,gemini,conservative,bachelor's
# 55603,2012,40.0,14.0,Protestant,pretty happy,cancer,slightly conservative,high school
# 55604,2012,50.0,16.0,Protestant,very happy,scorpio,conservative,bachelor's
# 55605,2012,48.0,8.0,Protestant,pretty happy,taurus,"moderate, middle of the road",less than high school
# 55606,2012,32.0,9.0,Catholic,pretty happy,pisces,slightly liberal,less than high school
# 55607,2012,41.0,8.0,Protestant,very happy,aries,slightly conservative,less than high school
# 55608,2012,26.0,9.0,Catholic,pretty happy,libra,extremely liberal,less than high school
# 55609,2012,57.0,12.0,Protestant,not too happy,virgo,liberal,high school
# 55610,2012,30.0,12.0,None,not too happy,sagittarius,"moderate, middle of the road",high school
# 55611,2012,41.0,12.0,Protestant,not too happy,cancer,extremely conservative,high school
# 55612,2012,50.0,9.0,Protestant,pretty happy,aquarius,slightly liberal,less than high school
# 55613,2012,30.0,15.0,Protestant,pretty happy,aquarius,liberal,high school
# 55614,2012,47.0,12.0,Protestant,pretty happy,taurus,"moderate, middle of the road",high school
# 55615,2012,65.0,7.0,Protestant,pretty happy,pisces,"moderate, middle of the road",less than high school
# 55616,2012,43.0,5.0,Catholic,not too happy,cancer,liberal,less than high school
# 55617,2012,20.0,14.0,Protestant,pretty happy,leo,slightly liberal,high school
# 55618,2012,47.0,18.0,Protestant,pretty happy,capricorn,"moderate, middle of the road",graduate
# 55619,2012,31.0,16.0,Christian,pretty happy,aquarius,liberal,bachelor's
# 55620,2012,35.0,12.0,Protestant,pretty happy,virgo,slightly liberal,high school
# 55621,2012,58.0,12.0,Catholic,pretty happy,virgo,,high school
# 55622,2012,66.0,14.0,Protestant,pretty happy,libra,slightly conservative,high school
# 55623,2012,37.0,12.0,Protestant,pretty happy,gemini,"moderate, middle of the road",high school
# 55624,2012,40.0,15.0,Protestant,pretty happy,sagittarius,slightly conservative,associate/junior college
# 55625,2012,56.0,13.0,Protestant,pretty happy,pisces,slightly conservative,high school
# 55626,2012,49.0,12.0,Protestant,pretty happy,gemini,,high school
# 55627,2012,30.0,14.0,Protestant,pretty happy,gemini,conservative,associate/junior college
# 55628,2012,45.0,18.0,Protestant,pretty happy,capricorn,"moderate, middle of the road",graduate
# 55629,2012,77.0,13.0,Protestant,pretty happy,libra,slightly liberal,high school
# 55630,2012,30.0,11.0,Protestant,pretty happy,aquarius,"moderate, middle of the road",less than high school
# 55631,2012,43.0,10.0,Protestant,very happy,capricorn,conservative,less than high school
# 55632,2012,31.0,13.0,Protestant,pretty happy,aquarius,"moderate, middle of the road",high school
# 55633,2012,58.0,16.0,Protestant,pretty happy,pisces,"moderate, middle of the road",bachelor's
# 55634,2012,62.0,12.0,Protestant,pretty happy,taurus,"moderate, middle of the road",high school
# 55635,2012,73.0,10.0,None,not too happy,taurus,,less than high school
# 55636,2012,60.0,12.0,Protestant,very happy,gemini,extremely liberal,high school
# 55637,2012,32.0,11.0,Protestant,very happy,scorpio,"moderate, middle of the road",less than high school
# 55638,2012,24.0,10.0,Protestant,very happy,sagittarius,"moderate, middle of the road",less than high school
# 55639,2012,71.0,14.0,None,not too happy,pisces,slightly liberal,high school
# 55640,2012,31.0,15.0,Christian,pretty happy,leo,"moderate, middle of the road",associate/junior college
# 55641,2012,42.0,14.0,Other,pretty happy,aquarius,slightly conservative,associate/junior college
# 55642,2012,80.0,10.0,Protestant,pretty happy,libra,"moderate, middle of the road",less than high school
# 55643,2012,76.0,12.0,Protestant,pretty happy,aquarius,extremely liberal,high school
# 55644,2012,40.0,11.0,Protestant,pretty happy,virgo,liberal,less than high school
# 55645,2012,29.0,10.0,Protestant,pretty happy,taurus,"moderate, middle of the road",less than high school
# 55646,2012,86.0,10.0,Protestant,very happy,libra,slightly conservative,less than high school
# 55647,2012,53.0,12.0,None,very happy,capricorn,slightly liberal,high school
# 55648,2012,48.0,12.0,Catholic,pretty happy,gemini,,high school
# 55649,2012,86.0,6.0,Protestant,pretty happy,cancer,liberal,less than high school
# 55650,2012,71.0,12.0,Catholic,not too happy,leo,,high school
# 55651,2012,50.0,6.0,Protestant,very happy,,,less than high school
# 55652,2012,40.0,14.0,Protestant,pretty happy,aquarius,slightly conservative,high school
# 55653,2012,30.0,12.0,Protestant,very happy,leo,slightly conservative,high school
# 55654,2012,68.0,6.0,Catholic,pretty happy,sagittarius,slightly conservative,less than high school
# 55655,2012,37.0,17.0,Christian,pretty happy,libra,slightly conservative,graduate
# 55656,2012,41.0,11.0,None,very happy,taurus,extremely conservative,high school
# 55657,2012,64.0,15.0,Catholic,not too happy,aquarius,conservative,associate/junior college
# 55658,2012,72.0,13.0,Catholic,pretty happy,leo,extremely conservative,high school
# 55659,2012,40.0,19.0,None,pretty happy,leo,"moderate, middle of the road",bachelor's
# 55660,2012,43.0,16.0,Protestant,very happy,capricorn,slightly conservative,bachelor's
# 55661,2012,84.0,17.0,Unknown,pretty happy,taurus,slightly conservative,graduate
# 55662,2012,34.0,16.0,Catholic,very happy,cancer,slightly conservative,bachelor's
# 55663,2012,79.0,14.0,Protestant,very happy,scorpio,conservative,associate/junior college
# 55664,2012,60.0,10.0,Christian,not too happy,aries,"moderate, middle of the road",less than high school
# ...
# 72204,2022,32.0,12.0,Catholic,very happy,virgo,conservative,high school
# 72205,2022,38.0,12.0,None,not too happy,leo,conservative,high school
# 72206,2022,38.0,12.0,Protestant,pretty happy,scorpio,"moderate, middle of the road",high school
# 72207,2022,62.0,12.0,Catholic,pretty happy,gemini,liberal,high school
# 72208,2022,,14.0,None,pretty happy,,"moderate, middle of the road",high school
# 72209,2022,70.0,12.0,Catholic,pretty happy,libra,"moderate, middle of the road",high school
# 72210,2022,42.0,16.0,None,pretty happy,pisces,"moderate, middle of the road",bachelor's
# 72211,2022,31.0,15.0,None,not too happy,aries,liberal,high school
# 72212,2022,63.0,14.0,Protestant,pretty happy,pisces,conservative,associate/junior college
# 72213,2022,50.0,16.0,Catholic,not too happy,aries,liberal,high school
# 72214,2022,35.0,17.0,Protestant,very happy,cancer,slightly conservative,graduate
# 72215,2022,39.0,16.0,None,pretty happy,gemini,"moderate, middle of the road",bachelor's
# 72216,2022,40.0,13.0,Protestant,very happy,gemini,conservative,high school
# 72217,2022,62.0,12.0,Catholic,pretty happy,pisces,"moderate, middle of the road",high school
# 72218,2022,67.0,13.0,Catholic,pretty happy,gemini,liberal,high school
# 72219,2022,57.0,12.0,Catholic,pretty happy,taurus,liberal,high school
# 72220,2022,46.0,16.0,Protestant,pretty happy,libra,conservative,bachelor's
# 72221,2022,28.0,16.0,Protestant,very happy,virgo,extremely conservative,bachelor's
# 72222,2022,74.0,20.0,Protestant,very happy,leo,"moderate, middle of the road",graduate
# 72223,2022,66.0,12.0,Protestant,pretty happy,capricorn,conservative,high school
# 72224,2022,53.0,14.0,Buddhism,not too happy,pisces,liberal,associate/junior college
# 72225,2022,43.0,14.0,Protestant,not too happy,capricorn,extremely liberal,high school
# 72226,2022,42.0,14.0,Catholic,not too happy,virgo,slightly conservative,associate/junior college
# 72227,2022,65.0,14.0,Catholic,pretty happy,gemini,slightly conservative,associate/junior college
# 72228,2022,75.0,19.0,Protestant,very happy,libra,slightly conservative,bachelor's
# 72229,2022,72.0,20.0,Catholic,pretty happy,virgo,extremely conservative,bachelor's
# 72230,2022,69.0,16.0,Catholic,pretty happy,libra,slightly liberal,bachelor's
# 72231,2022,27.0,14.0,Protestant,very happy,virgo,conservative,high school
# 72232,2022,29.0,20.0,None,not too happy,aquarius,liberal,graduate
# 72233,2022,67.0,12.0,Protestant,pretty happy,scorpio,"moderate, middle of the road",high school
# 72234,2022,41.0,12.0,Protestant,pretty happy,sagittarius,extremely conservative,high school
# 72235,2022,74.0,16.0,Protestant,pretty happy,capricorn,slightly conservative,bachelor's
# 72236,2022,64.0,12.0,None,pretty happy,scorpio,liberal,high school
# 72237,2022,,14.0,Protestant,pretty happy,,conservative,associate/junior college
# 72238,2022,34.0,12.0,Unknown,pretty happy,capricorn,"moderate, middle of the road",high school
# 72239,2022,35.0,14.0,Christian,very happy,pisces,"moderate, middle of the road",high school
# 72240,2022,21.0,12.0,None,pretty happy,pisces,"moderate, middle of the road",high school
# 72241,2022,42.0,12.0,None,pretty happy,pisces,"moderate, middle of the road",high school
# 72242,2022,68.0,12.0,Protestant,pretty happy,aquarius,"moderate, middle of the road",high school
# 72243,2022,39.0,15.0,None,not too happy,cancer,"moderate, middle of the road",high school
# 72244,2022,31.0,12.0,None,pretty happy,leo,extremely liberal,high school
# 72245,2022,69.0,11.0,Protestant,very happy,gemini,"moderate, middle of the road",less than high school
# 72246,2022,77.0,16.0,Protestant,pretty happy,virgo,"moderate, middle of the road",associate/junior college
# 72247,2022,23.0,12.0,Catholic,very happy,capricorn,"moderate, middle of the road",high school
# 72248,2022,22.0,12.0,None,pretty happy,pisces,"moderate, middle of the road",high school
# 72249,2022,47.0,12.0,Protestant,pretty happy,gemini,extremely conservative,less than high school
# 72250,2022,45.0,14.0,Buddhism,pretty happy,aquarius,slightly conservative,associate/junior college
# 72251,2022,50.0,16.0,Protestant,very happy,leo,"moderate, middle of the road",bachelor's
# 72252,2022,61.0,18.0,Catholic,pretty happy,,conservative,bachelor's
# 72253,2022,55.0,17.0,None,not too happy,sagittarius,extremely liberal,bachelor's
# 72254,2022,26.0,14.0,Catholic,very happy,scorpio,extremely conservative,high school
# 72255,2022,85.0,13.0,Protestant,pretty happy,cancer,"moderate, middle of the road",high school
# 72256,2022,76.0,12.0,Protestant,not too happy,cancer,"moderate, middle of the road",high school
# 72257,2022,69.0,11.0,Protestant,pretty happy,sagittarius,"moderate, middle of the road",high school
# 72258,2022,40.0,15.0,Protestant,pretty happy,virgo,conservative,high school
# 72259,2022,72.0,12.0,Protestant,pretty happy,pisces,conservative,high school
# 72260,2022,33.0,15.0,Protestant,pretty happy,cancer,conservative,high school
# 72261,2022,43.0,14.0,Protestant,very happy,aquarius,conservative,graduate
# 72262,2022,61.0,14.0,Protestant,very happy,virgo,extremely liberal,associate/junior college
# 72263,2022,68.0,13.0,Protestant,pretty happy,sagittarius,conservative,high school
# 72264,2022,62.0,12.0,Protestant,pretty happy,gemini,liberal,high school
# 72265,2022,52.0,9.0,Protestant,not too happy,taurus,extremely conservative,less than high school
# 72266,2022,,12.0,Unknown,pretty happy,,liberal,high school
# 72267,2022,70.0,9.0,Protestant,very happy,aries,"moderate, middle of the road",less than high school
# 72268,2022,33.0,3.0,None,not too happy,taurus,"moderate, middle of the road",less than high school
# 72269,2022,55.0,15.0,Protestant,not too happy,gemini,conservative,associate/junior college
# 72270,2022,,12.0,Unknown,pretty happy,,"moderate, middle of the road",high school
# 72271,2022,,,Unknown,pretty happy,,"moderate, middle of the road",less than high school
# 72272,2022,,16.0,Unknown,very happy,aquarius,extremely liberal,bachelor's
# 72273,2022,64.0,12.0,Protestant,not too happy,pisces,"moderate, middle of the road",high school
# 72274,2022,,12.0,Unknown,pretty happy,,liberal,high school
# 72275,2022,25.0,9.0,None,not too happy,gemini,"moderate, middle of the road",high school
# 72276,2022,84.0,10.0,Protestant,pretty happy,libra,"moderate, middle of the road",less than high school
# 72277,2022,49.0,12.0,None,pretty happy,cancer,"moderate, middle of the road",high school
# 72278,2022,60.0,12.0,Protestant,not too happy,taurus,"moderate, middle of the road",high school
# 72279,2022,26.0,12.0,None,not too happy,virgo,slightly liberal,high school
# 72280,2022,25.0,13.0,Protestant,very happy,aries,"moderate, middle of the road",high school
# 72281,2022,54.0,16.0,Protestant,pretty happy,libra,conservative,bachelor's
# 72282,2022,50.0,12.0,Protestant,pretty happy,libra,conservative,high school
# 72283,2022,38.0,14.0,None,pretty happy,leo,"moderate, middle of the road",bachelor's
# 72284,2022,66.0,10.0,Protestant,pretty happy,pisces,slightly liberal,less than high school
# 72285,2022,72.0,16.0,Protestant,pretty happy,scorpio,slightly liberal,bachelor's
# 72286,2022,54.0,12.0,Protestant,pretty happy,libra,slightly conservative,high school
# 72287,2022,51.0,11.0,Protestant,not too happy,cancer,conservative,less than high school
# 72288,2022,71.0,10.0,Protestant,not too happy,pisces,"moderate, middle of the road",less than high school
# 72289,2022,45.0,12.0,Protestant,pretty happy,,liberal,high school
# 72290,2022,29.0,11.0,None,very happy,pisces,slightly conservative,less than high school
# 72291,2022,56.0,11.0,Protestant,not too happy,aquarius,"moderate, middle of the road",less than high school
# 72292,2022,52.0,12.0,Protestant,very happy,aries,conservative,high school
# 72293,2022,36.0,12.0,Protestant,pretty happy,taurus,,high school
# 72294,2022,33.0,13.0,Catholic,not too happy,scorpio,"moderate, middle of the road",high school
# 72295,2022,28.0,12.0,Protestant,pretty happy,libra,liberal,high school
# 72296,2022,51.0,12.0,Protestant,pretty happy,libra,liberal,high school
# 72297,2022,33.0,10.0,Protestant,not too happy,scorpio,conservative,less than high school
# 72298,2022,33.0,19.0,Protestant,pretty happy,gemini,conservative,graduate
# 72299,2022,34.0,13.0,Catholic,very happy,scorpio,"moderate, middle of the road",high school
# 72300,2022,49.0,12.0,Protestant,very happy,,slightly conservative,high school
# 72301,2022,31.0,10.0,Protestant,pretty happy,virgo,extremely conservative,less than high school
# 72302,2022,40.0,18.0,Protestant,pretty happy,cancer,conservative,bachelor's
# 72303,2022,33.0,14.0,Protestant,pretty happy,virgo,"moderate, middle of the road",associate/junior college
# 72304,2022,55.0,12.0,Protestant,pretty happy,capricorn,slightly conservative,high school
# 72305,2022,49.0,11.0,Protestant,not too happy,gemini,conservative,high school
# 72306,2022,40.0,13.0,Protestant,very happy,gemini,conservative,high school
# 72307,2022,22.0,7.0,Protestant,not too happy,cancer,slightly liberal,less than high school
# 72308,2022,,13.0,None,not too happy,,"moderate, middle of the road",high school
# 72309,2022,43.0,10.0,None,not too happy,taurus,"moderate, middle of the road",less than high school
# 72310,2022,51.0,11.0,Protestant,pretty happy,gemini,extremely conservative,less than high school
# 72311,2022,20.0,14.0,Protestant,very happy,aries,conservative,high school
# 72312,2022,28.0,13.0,Protestant,very happy,sagittarius,slightly conservative,high school
# 72313,2022,34.0,9.0,Protestant,not too happy,capricorn,extremely liberal,less than high school
# 72314,2022,29.0,15.0,Catholic,not too happy,taurus,slightly conservative,high school
# 72315,2022,40.0,16.0,Protestant,very happy,capricorn,"moderate, middle of the road",bachelor's
# 72316,2022,33.0,5.0,Protestant,pretty happy,scorpio,liberal,less than high school
# 72317,2022,74.0,12.0,Protestant,pretty happy,capricorn,"moderate, middle of the road",high school
# 72318,2022,74.0,12.0,Protestant,pretty happy,aquarius,"moderate, middle of the road",high school
# 72319,2022,59.0,5.0,Protestant,pretty happy,pisces,"moderate, middle of the road",less than high school
# 72320,2022,28.0,12.0,None,pretty happy,virgo,slightly conservative,high school
# 72321,2022,24.0,12.0,Protestant,pretty happy,pisces,slightly liberal,high school
# 72322,2022,42.0,18.0,Protestant,pretty happy,gemini,"moderate, middle of the road",graduate
# 72323,2022,21.0,12.0,None,not too happy,scorpio,"moderate, middle of the road",high school
# 72324,2022,31.0,,None,not too happy,aquarius,"moderate, middle of the road",less than high school
# 72325,2022,73.0,14.0,Protestant,not too happy,cancer,extremely conservative,associate/junior college
# 72326,2022,66.0,12.0,Protestant,pretty happy,pisces,conservative,high school
# 72327,2022,27.0,15.0,Protestant,pretty happy,leo,"moderate, middle of the road",high school
# 72328,2022,46.0,12.0,Protestant,pretty happy,leo,"moderate, middle of the road",high school
# 72329,2022,69.0,12.0,Protestant,pretty happy,gemini,extremely conservative,high school
# 72330,2022,66.0,14.0,Protestant,very happy,aries,"moderate, middle of the road",associate/junior college
# 72331,2022,41.0,14.0,Protestant,pretty happy,leo,"moderate, middle of the road",high school
# 72332,2022,25.0,14.0,None,pretty happy,capricorn,extremely conservative,high school
# 72333,2022,84.0,7.0,Protestant,pretty happy,taurus,"moderate, middle of the road",less than high school
# 72334,2022,31.0,16.0,None,pretty happy,aquarius,extremely liberal,bachelor's
# 72335,2022,64.0,14.0,Protestant,not too happy,capricorn,slightly conservative,associate/junior college
# 72336,2022,30.0,16.0,None,pretty happy,scorpio,slightly liberal,bachelor's
# 72337,2022,67.0,16.0,Unknown,very happy,virgo,extremely liberal,graduate
# 72338,2022,54.0,20.0,Protestant,not too happy,pisces,liberal,bachelor's
# 72339,2022,66.0,10.0,Protestant,very happy,leo,extremely conservative,less than high school
# 72340,2022,36.0,18.0,Protestant,very happy,aquarius,"moderate, middle of the road",graduate
# 72341,2022,57.0,12.0,Protestant,pretty happy,virgo,"moderate, middle of the road",high school
# 72342,2022,81.0,12.0,Protestant,very happy,aries,extremely conservative,high school
# 72343,2022,25.0,12.0,Protestant,very happy,leo,conservative,high school
# 72344,2022,42.0,12.0,Other,pretty happy,libra,liberal,high school
# 72345,2022,29.0,14.0,None,very happy,pisces,"moderate, middle of the road",associate/junior college
# 72346,2022,66.0,12.0,Protestant,very happy,taurus,extremely liberal,high school
# 72347,2022,64.0,12.0,Protestant,not too happy,virgo,slightly conservative,high school
# 72348,2022,62.0,11.0,Protestant,pretty happy,taurus,slightly liberal,less than high school
# 72349,2022,31.0,12.0,None,pretty happy,capricorn,slightly liberal,high school
# 72350,2022,65.0,14.0,Protestant,not too happy,taurus,conservative,associate/junior college
# 72351,2022,78.0,18.0,Catholic,very happy,gemini,"moderate, middle of the road",graduate
# 72352,2022,54.0,16.0,None,pretty happy,pisces,liberal,bachelor's
# 72353,2022,53.0,16.0,Catholic,pretty happy,aries,"moderate, middle of the road",bachelor's
# 72354,2022,80.0,14.0,Protestant,very happy,aquarius,"moderate, middle of the road",high school
# 72355,2022,78.0,12.0,Protestant,pretty happy,pisces,"moderate, middle of the road",high school
# 72356,2022,86.0,11.0,Protestant,pretty happy,capricorn,conservative,high school
# 72357,2022,67.0,12.0,Protestant,very happy,scorpio,conservative,high school
# 72358,2022,27.0,18.0,Protestant,very happy,taurus,slightly conservative,graduate
# 72359,2022,51.0,20.0,Protestant,pretty happy,taurus,slightly conservative,graduate
# 72360,2022,77.0,13.0,Protestant,very happy,aries,slightly liberal,high school
# 72361,2022,67.0,12.0,Protestant,pretty happy,cancer,extremely liberal,high school
# 72362,2022,38.0,20.0,Protestant,pretty happy,taurus,"moderate, middle of the road",graduate
# 72363,2022,25.0,14.0,Protestant,very happy,aquarius,slightly conservative,associate/junior college
# 72364,2022,,16.0,None,pretty happy,,liberal,bachelor's
# 72365,2022,74.0,14.0,Protestant,not too happy,aries,liberal,high school
# 72366,2022,85.0,17.0,None,not too happy,sagittarius,extremely liberal,bachelor's
# 72367,2022,58.0,12.0,Protestant,very happy,taurus,"moderate, middle of the road",high school
# 72368,2022,30.0,16.0,Protestant,pretty happy,taurus,slightly liberal,bachelor's
# 72369,2022,74.0,12.0,Protestant,pretty happy,capricorn,slightly conservative,high school
# 72370,2022,29.0,12.0,None,pretty happy,cancer,"moderate, middle of the road",high school
# 72371,2022,29.0,12.0,None,not too happy,cancer,slightly liberal,high school
# 72372,2022,78.0,11.0,Protestant,pretty happy,scorpio,"moderate, middle of the road",less than high school
# 72373,2022,63.0,14.0,Protestant,pretty happy,aquarius,slightly liberal,high school
# 72374,2022,71.0,11.0,Protestant,pretty happy,leo,conservative,high school
# 72375,2022,72.0,15.0,Protestant,not too happy,taurus,conservative,high school
# 72376,2022,60.0,12.0,Protestant,not too happy,virgo,conservative,high school
# 72377,2022,64.0,16.0,Protestant,very happy,scorpio,conservative,bachelor's
# 72378,2022,61.0,16.0,Protestant,not too happy,gemini,slightly conservative,bachelor's
# 72379,2022,66.0,17.0,Unknown,not too happy,leo,liberal,graduate
# 72380,2022,49.0,16.0,Protestant,pretty happy,aquarius,"moderate, middle of the road",bachelor's
# 72381,2022,50.0,12.0,Catholic,pretty happy,taurus,slightly liberal,high school
# 72382,2022,69.0,14.0,Protestant,pretty happy,cancer,slightly liberal,high school
# 72383,2022,66.0,17.0,None,very happy,libra,liberal,bachelor's
# 72384,2022,78.0,16.0,Protestant,pretty happy,leo,slightly liberal,graduate
# 72385,2022,73.0,9.0,Protestant,not too happy,virgo,extremely conservative,less than high school
# 72386,2022,84.0,12.0,Protestant,not too happy,cancer,conservative,high school
# 72387,2022,22.0,12.0,Other,pretty happy,capricorn,extremely liberal,high school
# 72388,2022,29.0,19.0,Catholic,pretty happy,cancer,"moderate, middle of the road",graduate
# 72389,2022,32.0,15.0,None,pretty happy,scorpio,slightly liberal,associate/junior college
# 72390,2022,49.0,17.0,None,very happy,scorpio,slightly liberal,graduate
# 72391,2022,50.0,20.0,None,pretty happy,libra,liberal,graduate

# %% [markdown]
# Download CSV file:

# %%
from google.colab import files
files.download('cleaned_gss_data.csv')
